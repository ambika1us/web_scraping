# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     680                                   Pulp Fiction
# 11  372058                                     Your Name.
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# 15     346                                  Seven Samurai
# 16     769                                     GoodFellas
# 17   12477                         Grave of the Fireflies
# 18  157336                                   Interstellar
# 19   11216                                Cinema Paradiso
#
#                                              overview release_date  \
# 0   Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   In the continuing saga of the Corleone crime f...   1974-12-20
# 3   The true story of how businessman Oskar Schind...   1993-12-15
# 4   The defense and the prosecution have rested an...   1957-04-10
# 5   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 6   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 7   Batman raises the stakes in his war on crime. ...   2008-07-16
# 8   A supernatural tale set on death row in a Sout...   1999-12-10
# 9   All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 10  A burger-loving hit man, his philosophical par...   1994-09-10
# 11  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 12  As armies mass for a final battle that will de...   2003-12-17
# 13  A man with a low IQ has accomplished great thi...   1994-06-23
# 14  While the Civil War rages on between the Union...   1966-12-22
# 15  A samurai answers a village's request for prot...   1954-04-26
# 16  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 17  In the final months of World War II, 14-year-o...   1988-04-16
# 18  The adventures of a group of explorers who mak...   2014-11-05
# 19  A filmmaker recalls his childhood, when he fel...   1988-11-17
#
#     popularity  vote_average  vote_count
# 0      173.309         8.700       27605
# 1      191.266         8.689       20943
# 2       83.281         8.570       12634
# 3      175.351         8.567       16079
# 4       81.574         8.500        8824
# 5       95.201         8.500       16757
# 6       33.510         8.500        4453
# 7      151.801         8.519       33296
# 8       95.295         8.506       17720
# 9      119.278         8.500       18564
# 10     109.388         8.488       28225
# 11      73.192         8.485       11541
# 12     161.163         8.483       24548
# 13      97.065         8.470       27754
# 14      98.989         8.463        8759
# 15      40.546         8.500        3769
# 16      68.015         8.458       13055
# 17       0.055         8.453        5667
# 18     321.485         8.449       36293
# 19      39.753         8.448        4431

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    #df = df.concat(temp_df,ignore_index=True)
    df = pd.concat([df,temp_df], ignore_index=True)

# %%
df
# Out:
#           id                           title  \
# 0        278        The Shawshank Redemption
# 1        238                   The Godfather
# 2        240           The Godfather Part II
# 3        424                Schindler's List
# 4        389                    12 Angry Men
# ...      ...                             ...
# 8555   44943             Battle: Los Angeles
# 8556   10069                      Stay Alive
# 8557  305932                        Expelled
# 8558   82505  House at the End of the Street
# 8559   14906                  Saludos Amigos
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  When once distant UFOs become a terrifying thr...   2011-03-08
# 8556  After the brutal death of a friend, a group of...   2006-03-24
# 8557  Felix is a legendary prankster who gets expell...   2014-12-12
# 8558  A mother and daughter move to a new town and f...   2012-09-21
# 8559  A whimsical blend of live action and animation...   1942-08-24
#
#       popularity  vote_average  vote_count
# 0        173.309         8.700       27605
# 1        191.266         8.689       20943
# 2         83.281         8.570       12634
# 3        175.351         8.567       16079
# 4         81.574         8.500        8824
# ...          ...           ...         ...
# 8555      26.815         5.800        3465
# 8556      10.802         5.800         755
# 8557       7.543         5.800         449
# 8558      16.149         5.803        1796
# 8559      13.899         5.800         466
#
# [8560 rows x 7 columns]

# %%
df.to_csv('movies.csv')
